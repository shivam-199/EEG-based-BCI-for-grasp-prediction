# %%
import numpy as np
import pandas as pd
import os
import glob
import mne

# from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Analysis Plan
# ## Experiments
# 1. Left vs. Right
# 2. Inward vs. Upward vs. Downward
# 3. Open and close vs. Rest
# 4. Open vs. Close
#     1. ROIs
#     2. Contralteral and Ipsilateral classification
#     3. Non-ROI classification
#
# ## Features
# - [x] Power Spectral Density
# - [x] Spectopo Plots
# - [x] Time-series
# - [x] ICA Activations
# - [ ] ERS and ERD
#
# ## Algorithms
# 1. ML
#     1. PSD [band-wise and entire-band]
#     2. Time-series
# 2. CNN
#     1. spectopo
# 3. LSTM
#     1. time-series

# %% [markdown]
# # 1. Frequency Domain [PSD]

# %%
dataset = pd.read_csv("/mnt/sda1/shivam/Thesis/Grasp Experiment/Data/CleanSep/cleaned_data_asr.csv")
dataset

# %%
# Find list of channels available for every participant
chans, chan_count = np.unique(dataset["Channel"], return_counts=True)
good_chans = [i+1 for i in range(len(chan_count)) if chan_count[i] == 6240]
print(len(good_chans))
print(good_chans)

# %%
# Subject-wise channel availability
sub_good_chans = {}
for sub in np.unique(dataset["Subject"]):
    sub_good_chans[sub] = np.unique(dataset[dataset["Subject"] == sub]["Channel"]) 
sub_good_chans

# %%
os.chdir("/mnt/sda1/shivam/Thesis/Grasp Experiment/Data/IntData/ASR")
psd_data = pd.read_csv("psd_features_v1.csv", header=None, names=list(range(1, 385)))
psd_oc = np.load("psd_oc_labels.npy")
psd_lr = np.load("psd_lr_labels.npy")
psd_pos = np.load("psd_handpos_labels.npy")
psd_chan = np.load("psd_chans_labels.npy", allow_pickle=True)
psd_sub = np.load("psd_subjs_labels.npy", allow_pickle=True)

psd_data.shape,

# %%
psd_data

# %%
req_chan_idx = {}
for key in sub_good_chans.keys():
    req_chan_idx[key] = [i for i in range(len(sub_good_chans[key])) if sub_good_chans[key][i] in good_chans] 
print(req_chan_idx)

# %%
# Extract PSD data for common good channels
subjects = list(req_chan_idx.keys())
ntrials = 480
eeg_data = np.array(())
for i in range(len(subjects)):
    
    # Selecting rows
    row_start = i * ntrials
    row_end = (i+1) * ntrials
    
    # Selecting columns based on good channels
    p_eeg = np.array(())
    cols = req_chan_idx[subjects[i]]
    for ii in cols:
        col_start = (ii) * 6 
        col_end = (ii+1) * 6
        
        if p_eeg.shape[0] != 0:
            p_eeg = np.concatenate((p_eeg, psd_data.iloc[row_start: row_end, col_start: col_end].to_numpy()), axis=1)
        else:
            p_eeg = psd_data.iloc[row_start: row_end, col_start: col_end].to_numpy()    
    
    eeg_data = p_eeg if eeg_data.shape[0] == 0 else np.concatenate((eeg_data, p_eeg))

eeg_data_df = pd.DataFrame(np.array(eeg_data))
eeg_data_df.head()

# %%
X = eeg_data_df.to_numpy()
y = psd_lr

# y = psd_pos
# y = psd_oc
X.shape, y.shape

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import load_iris
from sklearn.svm import SVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# Define the parameter grids for each classifier
xgb_param_grid = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.1, 0.05, 0.01]
}

lgbm_param_grid = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.1, 0.05, 0.01]
}

svc_param_grid = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf']
}

# Define the classifiers
xgb_clf = XGBClassifier()
lgbm_clf = LGBMClassifier()
svc_clf = SVC()

# Create a dictionary of classifiers and their corresponding parameter grids
classifiers = {
    'XGBoost': (xgb_clf, xgb_param_grid),
    'LightGBM': (lgbm_clf, lgbm_param_grid),
    'SVC': (svc_clf, svc_param_grid)
}

grid_scores_list = []
# Perform grid search cross-validation for each classifier
for clf_name, (clf, param_grid) in classifiers.items():
    grid_search = GridSearchCV(clf, param_grid=param_grid, cv=5, scoring='accuracy')
    grid_search.fit(X_red, y)
    
    print(f"Results for {clf_name}:")
    print("Best parameters:", grid_search.best_params_)
    print("Best score:", grid_search.best_score_)
    print()
    grid_scores_list.append(grid_search.cv_results_)

# %%
import pickle
os.chdir("/mnt/sda1/shivam/Thesis/Grasp Experiment/Data/Results/GridSearchCV")
with open("gscv-psd-left-right.pkl", "wb") as f:
    pickle.dump(grid_scores_list, f)

# %% [markdown]
# ## 6 bands

# %% [markdown]
# ### 1. Left vs. Right [6 band]

# %%
X_train, X_eval, y_train, y_eval = train_test_split(eeg_data_df, psd_lr, test_size=0.2, random_state=42)
X_train.shape, X_eval.shape, y_train.shape, y_eval.shape#, y_test.shape
# Out:
# ((4992, 288), (1248, 288), (4992,), (1248,))

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_eval, y_train, y_eval)
models
# Out:
# 100%|███████████████████████████████████████████| 29/29 [00:48<00:00,  1.67s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.83               0.83     0.83      0.83
# RandomForestClassifier             0.82               0.82     0.82      0.82
# LGBMClassifier                     0.82               0.82     0.82      0.82
# SVC                                0.81               0.81     0.81      0.81
# NuSVC                              0.80               0.80     0.80      0.80
# CalibratedClassifierCV             0.80               0.80     0.80      0.80
# ExtraTreesClassifier               0.80               0.80     0.80      0.80
# LinearSVC                          0.80               0.80     0.80      0.80
# BaggingClassifier                  0.79               0.79     0.79      0.79
# LogisticRegression                 0.79               0.79     0.79      0.79
# LinearDiscriminantAnalysis         0.78               0.78     0.78      0.78
# RidgeClassifier                    0.78               0.78     0.78      0.78
# RidgeClassifierCV                  0.78               0.78     0.78      0.78
# AdaBoostClassifier                 0.77               0.77     0.77      0.77
# SGDClassifier                      0.75               0.76     0.76      0.75
# Perceptron                         0.75               0.74     0.74      0.75
# DecisionTreeClassifier             0.70               0.70     0.70      0.70
# KNeighborsClassifier               0.68               0.68     0.68      0.68
# PassiveAggressiveClassifier        0.68               0.68     0.68      0.68
# QuadraticDiscriminantAnalysis      0.63               0.64     0.64      0.63
# ExtraTreeClassifier                0.61               0.61     0.61      0.61
# BernoulliNB                        0.60               0.60     0.60      0.60
# LabelSpreading                     0.59               0.59     0.59      0.57
# LabelPropagation                   0.58               0.59     0.59      0.57
# NearestCentroid                    0.58               0.58     0.58      0.57
# GaussianNB                         0.52               0.53     0.53      0.48
# DummyClassifier                    0.48               0.50     0.50      0.31
#
#                                Time Taken
# Model
# XGBClassifier                        3.61
# RandomForestClassifier               4.49
# LGBMClassifier                       1.21
# SVC                                  3.68
# NuSVC                                3.90
# CalibratedClassifierCV               9.68
# ExtraTreesClassifier                 0.99
# LinearSVC                            2.68
# BaggingClassifier                    7.93
# LogisticRegression                   0.11
# LinearDiscriminantAnalysis           0.17
# RidgeClassifier                      0.06
# RidgeClassifierCV                    0.09
# AdaBoostClassifier                   6.46
# SGDClassifier                        0.33
# Perceptron                           0.07
# DecisionTreeClassifier               1.44
# KNeighborsClassifier                 0.09
# PassiveAggressiveClassifier          0.09
# QuadraticDiscriminantAnalysis        0.11
# ExtraTreeClassifier                  0.05
# BernoulliNB                          0.05
# LabelSpreading                       0.52
# LabelPropagation                     0.43
# NearestCentroid                      0.05
# GaussianNB                           0.05
# DummyClassifier                      0.04

# %%
models.to_csv("/mnt/sda1/shivam/Thesis/Grasp Experiment/Data/Results/final/psd-left-vs-right-all.csv")

# %% [markdown]
# ### 2. Hand positions [6 band]

# %%
X_train, X_eval, y_train, y_eval = train_test_split(eeg_data_df, psd_pos, test_size=0.2, random_state=42)
X_train.shape, X_eval.shape, y_train.shape, y_eval.shape
# Out:
# ((4992, 288), (1248, 288), (4992,), (1248,))

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_eval, y_train, y_eval)
models
# Out:
# 100%|███████████████████████████████████████████| 29/29 [01:22<00:00,  2.84s/it]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.87               0.87    None      0.87
# LGBMClassifier                     0.86               0.86    None      0.86
# RandomForestClassifier             0.81               0.81    None      0.81
# ExtraTreesClassifier               0.80               0.80    None      0.80
# BaggingClassifier                  0.78               0.78    None      0.78
# NuSVC                              0.74               0.74    None      0.74
# KNeighborsClassifier               0.69               0.69    None      0.69
# SVC                                0.68               0.68    None      0.68
# DecisionTreeClassifier             0.65               0.65    None      0.65
# AdaBoostClassifier                 0.62               0.62    None      0.62
# CalibratedClassifierCV             0.60               0.61    None      0.61
# LinearSVC                          0.60               0.60    None      0.60
# LogisticRegression                 0.59               0.59    None      0.59
# QuadraticDiscriminantAnalysis      0.58               0.58    None      0.58
# RidgeClassifierCV                  0.58               0.58    None      0.58
# LinearDiscriminantAnalysis         0.58               0.58    None      0.58
# RidgeClassifier                    0.58               0.58    None      0.58
# ExtraTreeClassifier                0.55               0.55    None      0.55
# PassiveAggressiveClassifier        0.54               0.54    None      0.54
# LabelPropagation                   0.53               0.53    None      0.52
# LabelSpreading                     0.53               0.53    None      0.52
# SGDClassifier                      0.52               0.52    None      0.52
# Perceptron                         0.51               0.51    None      0.51
# GaussianNB                         0.42               0.42    None      0.37
# BernoulliNB                        0.40               0.40    None      0.40
# NearestCentroid                    0.39               0.39    None      0.37
# DummyClassifier                    0.33               0.33    None      0.16
#
#                                Time Taken
# Model
# XGBClassifier                        7.70
# LGBMClassifier                       2.06
# RandomForestClassifier               5.11
# ExtraTreesClassifier                 1.12
# BaggingClassifier                    8.42
# NuSVC                                5.31
# KNeighborsClassifier                 0.10
# SVC                                  4.54
# DecisionTreeClassifier               1.34
# AdaBoostClassifier                   6.58
# CalibratedClassifierCV              29.28
# LinearSVC                            8.09
# LogisticRegression                   0.21
# QuadraticDiscriminantAnalysis        0.12
# RidgeClassifierCV                    0.12
# LinearDiscriminantAnalysis           0.17
# RidgeClassifier                      0.06
# ExtraTreeClassifier                  0.05
# PassiveAggressiveClassifier          0.21
# LabelPropagation                     0.41
# LabelSpreading                       0.51
# SGDClassifier                        0.55
# Perceptron                           0.17
# GaussianNB                           0.06
# BernoulliNB                          0.05
# NearestCentroid                      0.06
# DummyClassifier                      0.04

# %%
models.to_csv("/mnt/sda1/shivam/Thesis/Grasp Experiment/Data/Results/final/psd-in-vs-up-vs-down-all.csv")

# %% [markdown]
# ### 3. Open vs. Close [6 band]

# %%
X_train, X_eval, y_train, y_eval = train_test_split(eeg_data_df, psd_oc, test_size=0.2, random_state=42)
X_train.shape, X_eval.shape, y_train.shape, y_eval.shape
# Out:
# ((4992, 288), (1248, 288), (4992,), (1248,))

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_eval, y_train, y_eval)
models
# Out:
# 100%|███████████████████████████████████████████| 29/29 [00:55<00:00,  1.92s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NuSVC                              0.56               0.56     0.56      0.56
# RandomForestClassifier             0.56               0.56     0.56      0.56
# LGBMClassifier                     0.55               0.55     0.55      0.55
# LogisticRegression                 0.55               0.55     0.55      0.55
# LinearDiscriminantAnalysis         0.55               0.55     0.55      0.55
# RidgeClassifierCV                  0.55               0.55     0.55      0.55
# RidgeClassifier                    0.55               0.55     0.55      0.55
# LinearSVC                          0.54               0.54     0.54      0.54
# SVC                                0.54               0.54     0.54      0.54
# ExtraTreesClassifier               0.54               0.54     0.54      0.54
# SGDClassifier                      0.54               0.54     0.54      0.53
# CalibratedClassifierCV             0.53               0.53     0.53      0.52
# NearestCentroid                    0.53               0.53     0.53      0.52
# AdaBoostClassifier                 0.53               0.53     0.53      0.53
# BernoulliNB                        0.53               0.53     0.53      0.53
# XGBClassifier                      0.53               0.53     0.53      0.53
# BaggingClassifier                  0.53               0.53     0.53      0.52
# QuadraticDiscriminantAnalysis      0.52               0.52     0.52      0.49
# GaussianNB                         0.52               0.52     0.52      0.46
# PassiveAggressiveClassifier        0.52               0.52     0.52      0.51
# KNeighborsClassifier               0.51               0.51     0.51      0.51
# Perceptron                         0.51               0.51     0.51      0.51
# DummyClassifier                    0.49               0.50     0.50      0.33
# LabelPropagation                   0.50               0.50     0.50      0.48
# LabelSpreading                     0.50               0.50     0.50      0.48
# DecisionTreeClassifier             0.49               0.49     0.49      0.49
# ExtraTreeClassifier                0.47               0.47     0.47      0.47
#
#                                Time Taken
# Model
# NuSVC                                5.95
# RandomForestClassifier               5.82
# LGBMClassifier                       0.62
# LogisticRegression                   0.12
# LinearDiscriminantAnalysis           0.25
# RidgeClassifierCV                    0.11
# RidgeClassifier                      0.08
# LinearSVC                            3.30
# SVC                                  4.38
# ExtraTreesClassifier                 1.37
# SGDClassifier                        0.31
# CalibratedClassifierCV              12.23
# NearestCentroid                      0.06
# AdaBoostClassifier                   6.46
# BernoulliNB                          0.06
# XGBClassifier                        2.01
# BaggingClassifier                    9.51
# QuadraticDiscriminantAnalysis        0.11
# GaussianNB                           0.05
# PassiveAggressiveClassifier          0.09
# KNeighborsClassifier                 0.10
# Perceptron                           0.09
# DummyClassifier                      0.04
# LabelPropagation                     0.47
# LabelSpreading                       0.55
# DecisionTreeClassifier               1.53
# ExtraTreeClassifier                  0.05

# %%
models.to_csv("/mnt/sda1/shivam/Thesis/Grasp Experiment/Data/Results/final/psd-open-vs-close-all.csv")

# %% [markdown]
# ## 2. Entire frequency band

# %%
eeg_data_all_df = eeg_data_df.iloc[:, ::-6].sort_index(axis=1)
eeg_data_all_df
# Out:
#        5     11   17     23    29    35    41    47    53    59   ...   233  \
# 0    95.39 34.22 5.35 175.52 15.72 37.32 23.85 59.09 30.64 43.27  ... 54.13
# 1    58.17 37.53 7.98 170.06 16.73 42.92 24.89 72.92 33.95 56.81  ... 41.05
# 2    46.54 36.19 5.86 130.36 18.13 36.16 28.91 82.26 32.43 51.05  ... 50.71
# 3    64.15 30.25 4.54 172.87 14.52 26.28 21.82 47.68 39.09 58.45  ... 24.36
# 4    69.18 31.91 7.55 144.77 16.25 27.93 32.94 62.69 47.32 64.05  ... 53.32
# ...    ...   ...  ...    ...   ...   ...   ...   ...   ...   ...  ...   ...
# 6235 91.57 21.74 3.81 336.91 33.04 96.07 34.85 77.83 20.64 19.44  ...  5.27
# 6236 64.01 10.70 2.52 171.88 12.99 40.51 11.33 25.59  6.14  4.40  ...  3.40
# 6237 76.18 16.06 3.07 219.93 16.02 41.35 11.18 25.25  7.60  8.36  ...  2.79
# 6238 33.26  7.59 2.87  46.36  6.33  8.23  7.93 12.22  6.88  8.18  ...  2.63
# 6239 63.98 13.34 5.98 139.39 16.73 40.28 11.72 30.97  7.70  8.61  ...  4.66
#
#        239   245   251   257   263   269   275   281    287
# 0    28.76 13.65 41.99 57.63 26.93 39.28 27.02 32.80  51.89
# 1    21.67 13.17 57.84 62.72 25.90 52.84 41.68 39.35  67.17
# 2    32.26 14.34 22.90 50.38 25.10 32.12 28.15 28.37  23.71
# 3    14.47  7.70 27.02 49.11 16.69 33.41 30.17 29.77  25.56
# 4    26.03 16.47 24.51 54.43 17.48 24.52 22.05 23.22  33.12
# ...    ...   ...   ...   ...   ...   ...   ...   ...    ...
# 6235  3.52  6.57 45.07  9.22  8.00 17.33 15.78 24.43 112.43
# 6236  2.24  2.86 14.40  6.13  7.16  7.66 22.27 22.14  26.90
# 6237  3.03  3.94 22.22 12.17 14.02 27.90 26.26 24.04  54.98
# 6238  2.83  2.34 22.55 20.32 11.27 35.21 39.37 15.00  54.01
# 6239  3.44  6.48 21.92 11.12 10.94 23.01 26.28 24.19  58.12
#
# [6240 rows x 48 columns]

# %%
entire_band_idx = list(eeg_data_all_df.columns)
print(entire_band_idx)
# Out:
# [5, 11, 17, 23, 29, 35, 41, 47, 53, 59, 65, 71, 77, 83, 89, 95, 101, 107, 113, 119, 125, 131, 137, 143, 149, 155, 161, 167, 173, 179, 185, 191, 197, 203, 209, 215, 221, 227, 233, 239, 245, 251, 257, 263, 269, 275, 281, 287]

# %% [markdown]
# ### 1. Left vs. Right

# %%
X_train, X_eval, y_train, y_eval = train_test_split(eeg_data_all_df.to_numpy(), psd_lr, test_size=0.2, random_state=42)
X_train.shape, X_eval.shape, y_train.shape, y_eval.shape
# Out:
# ((4992, 48), (1248, 48), (4992,), (1248,))

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train, X_eval, y_train, y_eval)
models
# Out:
# 100%|███████████████████████████████████████████| 29/29 [00:13<00:00,  2.10it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NuSVC                              0.80               0.80     0.80      0.80
# LGBMClassifier                     0.78               0.78     0.78      0.78
# SVC                                0.78               0.78     0.78      0.78
# XGBClassifier                      0.78               0.78     0.78      0.78
# RandomForestClassifier             0.77               0.77     0.77      0.77
# ExtraTreesClassifier               0.77               0.77     0.77      0.77
# CalibratedClassifierCV             0.77               0.76     0.76      0.77
# LogisticRegression                 0.77               0.76     0.76      0.77
# LinearSVC                          0.77               0.76     0.76      0.77
# AdaBoostClassifier                 0.75               0.75     0.75      0.75
# RidgeClassifier                    0.75               0.75     0.75      0.75
# LinearDiscriminantAnalysis         0.75               0.75     0.75      0.75
# RidgeClassifierCV                  0.75               0.75     0.75      0.75
# BaggingClassifier                  0.75               0.75     0.75      0.75
# SGDClassifier                      0.74               0.74     0.74      0.74
# Perceptron                         0.70               0.71     0.71      0.70
# KNeighborsClassifier               0.69               0.69     0.69      0.69
# DecisionTreeClassifier             0.69               0.69     0.69      0.69
# LabelSpreading                     0.68               0.68     0.68      0.68
# LabelPropagation                   0.68               0.68     0.68      0.68
# QuadraticDiscriminantAnalysis      0.65               0.65     0.65      0.65
# PassiveAggressiveClassifier        0.65               0.65     0.65      0.64
# ExtraTreeClassifier                0.62               0.62     0.62      0.62
# NearestCentroid                    0.61               0.62     0.62      0.61
# BernoulliNB                        0.61               0.61     0.61      0.61
# GaussianNB                         0.54               0.55     0.55      0.48
# DummyClassifier                    0.48               0.50     0.50      0.31
#
#                                Time Taken
# Model
# NuSVC                                1.64
# LGBMClassifier                       0.42
# SVC                                  1.40
# XGBClassifier                        0.72
# RandomForestClassifier               1.94
# ExtraTreesClassifier                 0.53
# CalibratedClassifierCV               2.46
# LogisticRegression                   0.06
# LinearSVC                            0.63
# AdaBoostClassifier                   1.32
# RidgeClassifier                      0.02
# LinearDiscriminantAnalysis           0.03
# RidgeClassifierCV                    0.02
# BaggingClassifier                    1.20
# SGDClassifier                        0.05
# Perceptron                           0.02
# KNeighborsClassifier                 0.06
# DecisionTreeClassifier               0.22
# LabelSpreading                       0.51
# LabelPropagation                     0.40
# QuadraticDiscriminantAnalysis        0.02
# PassiveAggressiveClassifier          0.04
# ExtraTreeClassifier                  0.02
# NearestCentroid                      0.01
# BernoulliNB                          0.02
# GaussianNB                           0.02
# DummyClassifier                      0.01

# %%
models.to_csv("/mnt/sda1/shivam/Thesis/Grasp Experiment/Data/Results/final/psd-left-vs-right-single.csv")

# %% [markdown]
# ### 2. Hand positions

# %%
X_train, X_eval, y_train, y_eval = train_test_split(eeg_data_all_df.to_numpy(), psd_pos, test_size=0.2, random_state=42)
X_train.shape, X_eval.shape, y_train.shape, y_eval.shape
# Out:
# ((4992, 48), (1248, 48), (4992,), (1248,))

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train, X_eval, y_train, y_eval)
models
# Out:
# 100%|███████████████████████████████████████████| 29/29 [00:23<00:00,  1.23it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.77               0.77    None      0.77
# XGBClassifier                      0.77               0.77    None      0.77
# ExtraTreesClassifier               0.75               0.75    None      0.75
# RandomForestClassifier             0.75               0.75    None      0.75
# NuSVC                              0.72               0.72    None      0.72
# BaggingClassifier                  0.71               0.71    None      0.71
# KNeighborsClassifier               0.69               0.69    None      0.69
# LabelSpreading                     0.67               0.67    None      0.67
# LabelPropagation                   0.67               0.67    None      0.67
# SVC                                0.65               0.65    None      0.65
# DecisionTreeClassifier             0.62               0.62    None      0.62
# AdaBoostClassifier                 0.55               0.55    None      0.55
# QuadraticDiscriminantAnalysis      0.53               0.54    None      0.52
# ExtraTreeClassifier                0.53               0.53    None      0.53
# CalibratedClassifierCV             0.52               0.52    None      0.52
# LinearSVC                          0.52               0.52    None      0.52
# LogisticRegression                 0.52               0.52    None      0.52
# LinearDiscriminantAnalysis         0.52               0.52    None      0.52
# RidgeClassifierCV                  0.51               0.52    None      0.51
# RidgeClassifier                    0.51               0.51    None      0.51
# PassiveAggressiveClassifier        0.49               0.49    None      0.49
# SGDClassifier                      0.46               0.46    None      0.46
# Perceptron                         0.42               0.42    None      0.41
# GaussianNB                         0.39               0.39    None      0.34
# NearestCentroid                    0.37               0.38    None      0.34
# BernoulliNB                        0.38               0.38    None      0.38
# DummyClassifier                    0.33               0.33    None      0.16
#
#                                Time Taken
# Model
# LGBMClassifier                       0.46
# XGBClassifier                        2.28
# ExtraTreesClassifier                 0.56
# RandomForestClassifier               2.03
# NuSVC                                2.33
# BaggingClassifier                    1.45
# KNeighborsClassifier                 0.05
# LabelSpreading                       0.52
# LabelPropagation                     0.39
# SVC                                  2.17
# DecisionTreeClassifier               0.29
# AdaBoostClassifier                   1.20
# QuadraticDiscriminantAnalysis        0.02
# ExtraTreeClassifier                  0.02
# CalibratedClassifierCV               7.32
# LinearSVC                            1.90
# LogisticRegression                   0.12
# LinearDiscriminantAnalysis           0.03
# RidgeClassifierCV                    0.03
# RidgeClassifier                      0.02
# PassiveAggressiveClassifier          0.05
# SGDClassifier                        0.14
# Perceptron                           0.03
# GaussianNB                           0.01
# NearestCentroid                      0.02
# BernoulliNB                          0.02
# DummyClassifier                      0.02

# %%
models.to_csv("/mnt/sda1/shivam/Thesis/Grasp Experiment/Data/Results/final/psd-in-vs-up-vs-down-single.csv")

# %% [markdown]
# ### 3. Open vs. Close

# %%
X_train, X_eval, y_train, y_eval = train_test_split(eeg_data_all_df.to_numpy(), psd_oc, test_size=0.2, random_state=42)
X_train.shape, X_eval.shape, y_train.shape, y_eval.shape
# Out:
# ((4992, 48), (1248, 48), (4992,), (1248,))

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train, X_eval, y_train, y_eval)
models
# Out:
# 100%|███████████████████████████████████████████| 29/29 [00:18<00:00,  1.57it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.54               0.54     0.54      0.54
# NuSVC                              0.53               0.53     0.53      0.53
# NearestCentroid                    0.53               0.53     0.53      0.52
# XGBClassifier                      0.52               0.52     0.52      0.52
# BaggingClassifier                  0.53               0.52     0.52      0.52
# ExtraTreeClassifier                0.52               0.52     0.52      0.52
# LGBMClassifier                     0.52               0.52     0.52      0.52
# RidgeClassifier                    0.52               0.52     0.52      0.52
# GaussianNB                         0.51               0.52     0.52      0.44
# LogisticRegression                 0.52               0.52     0.52      0.52
# LinearSVC                          0.52               0.52     0.52      0.52
# RidgeClassifierCV                  0.52               0.52     0.52      0.52
# AdaBoostClassifier                 0.52               0.52     0.52      0.52
# LinearDiscriminantAnalysis         0.52               0.52     0.52      0.51
# RandomForestClassifier             0.52               0.52     0.52      0.52
# KNeighborsClassifier               0.51               0.51     0.51      0.51
# SGDClassifier                      0.51               0.51     0.51      0.50
# QuadraticDiscriminantAnalysis      0.50               0.51     0.51      0.44
# SVC                                0.50               0.50     0.50      0.50
# BernoulliNB                        0.50               0.50     0.50      0.50
# LabelPropagation                   0.50               0.50     0.50      0.50
# DummyClassifier                    0.49               0.50     0.50      0.33
# LabelSpreading                     0.50               0.50     0.50      0.50
# DecisionTreeClassifier             0.50               0.50     0.50      0.50
# PassiveAggressiveClassifier        0.50               0.49     0.49      0.48
# CalibratedClassifierCV             0.48               0.49     0.49      0.42
# Perceptron                         0.49               0.49     0.49      0.46
#
#                                Time Taken
# Model
# ExtraTreesClassifier                 0.70
# NuSVC                                5.04
# NearestCentroid                      0.01
# XGBClassifier                        0.57
# BaggingClassifier                    1.74
# ExtraTreeClassifier                  0.02
# LGBMClassifier                       0.18
# RidgeClassifier                      0.02
# GaussianNB                           0.01
# LogisticRegression                   0.05
# LinearSVC                            0.69
# RidgeClassifierCV                    0.02
# AdaBoostClassifier                   1.19
# LinearDiscriminantAnalysis           0.03
# RandomForestClassifier               2.35
# KNeighborsClassifier                 0.06
# SGDClassifier                        0.07
# QuadraticDiscriminantAnalysis        0.02
# SVC                                  1.96
# BernoulliNB                          0.02
# LabelPropagation                     0.39
# DummyClassifier                      0.01
# LabelSpreading                       0.50
# DecisionTreeClassifier               0.30
# PassiveAggressiveClassifier          0.02
# CalibratedClassifierCV               2.52
# Perceptron                           0.02

# %%
models.to_csv("/mnt/sda1/shivam/Thesis/Grasp Experiment/Data/Results/final/psd-open-vs-close-single.csv")

# %% [markdown]
# ## 3. Five frequency bands

# %%
eeg_data_five_df = eeg_data_df.loc[:, ~eeg_data_df.columns.isin(entire_band_idx)]
eeg_data_five_df
# Out:
#         0      1     2     3     4      6     7     8     9    10   ...  \
# 0    105.91  58.18 12.12 59.74 21.83  59.88 40.13 13.30 14.01 5.43  ...
# 1    129.47  35.84 11.12 31.93 12.18  73.82 24.97 11.12 19.75 4.21  ...
# 2      8.50   5.93  7.91 22.95 14.49  10.13  5.37  7.52 19.70 7.14  ...
# 3      8.07   6.46  7.46 40.78 15.00   8.66  5.57  7.92 15.34 5.25  ...
# 4      7.97   4.92  6.73 44.15 18.40   4.58  4.43  6.80 17.36 5.65  ...
# ...     ...    ...   ...   ...   ...    ...   ...   ...   ...  ...  ...
# 6235 440.33 145.81 34.48 40.26 16.05 159.18 48.40 10.50  8.45 1.96  ...
# 6236 692.19 381.08 28.72 28.14  6.98 127.66 75.08  6.92  2.77 0.88  ...
# 6237 317.38 111.00 21.89 41.00 12.95  39.23 22.45  5.08  9.40 1.13  ...
# 6238  60.88  14.37  5.74 17.52  8.15  12.85  3.64  1.48  3.94 1.59  ...
# 6239 496.76 322.38 28.19 25.09  8.10 106.62 70.63  6.66  4.87 1.45  ...
#
#         276   277   278   279  280    282    283   284   285   286
# 0     35.96 20.13  6.95 19.23 5.31  40.18  29.64 10.02 30.27  9.30
# 1     30.04  9.57 10.46 19.41 7.71  52.03  32.51 30.59 20.01 12.13
# 2      6.05  3.99  6.47 15.36 4.98  23.28  11.84  5.78  9.55  8.58
# 3     10.18  4.78  6.27 14.34 8.24  28.88   9.81  7.47  7.84  9.91
# 4      9.29  3.76  4.81 11.83 5.45  31.87  12.68 11.66 13.39  7.04
# ...     ...   ...   ...   ...  ...    ...    ...   ...   ...   ...
# 6235  70.29 25.12  8.41 10.43 5.05 727.70 259.27 54.31 41.38 11.19
# 6236 108.67 68.99  7.57  8.63 5.47 302.60 159.04 17.64  6.81  1.96
# 6237  18.51 17.11  6.58 13.99 2.89 374.61 118.01 22.47 23.57  6.42
# 6238  14.98  8.06  2.87  6.78 4.83  87.70  74.98 32.02 16.02  4.51
# 6239  84.64 70.70 10.00 10.77 2.61 622.23 214.57 35.05 16.59  2.59
#
# [6240 rows x 240 columns]

# %% [markdown]
# ### 1. Left vs. Right

# %%
X_train, X_eval, y_train, y_eval = train_test_split(eeg_data_five_df.to_numpy(), psd_lr, test_size=0.2, random_state=42)
X_train.shape, X_eval.shape, y_train.shape, y_eval.shape
# Out:
# ((4992, 240), (1248, 240), (4992,), (1248,))

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train, X_eval, y_train, y_eval)
models
# Out:
# 100%|███████████████████████████████████████████| 29/29 [00:40<00:00,  1.40s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.83               0.83     0.83      0.83
# RandomForestClassifier             0.83               0.83     0.83      0.83
# XGBClassifier                      0.82               0.82     0.82      0.82
# NuSVC                              0.80               0.80     0.80      0.80
# SVC                                0.80               0.80     0.80      0.80
# CalibratedClassifierCV             0.79               0.79     0.79      0.79
# ExtraTreesClassifier               0.79               0.79     0.79      0.79
# LogisticRegression                 0.79               0.79     0.79      0.79
# LinearSVC                          0.79               0.79     0.79      0.79
# RidgeClassifierCV                  0.78               0.78     0.78      0.78
# RidgeClassifier                    0.77               0.77     0.77      0.77
# AdaBoostClassifier                 0.77               0.77     0.77      0.77
# LinearDiscriminantAnalysis         0.77               0.77     0.77      0.77
# BaggingClassifier                  0.76               0.76     0.76      0.76
# DecisionTreeClassifier             0.73               0.73     0.73      0.73
# Perceptron                         0.72               0.72     0.72      0.72
# SGDClassifier                      0.70               0.70     0.70      0.70
# KNeighborsClassifier               0.68               0.68     0.68      0.68
# PassiveAggressiveClassifier        0.67               0.67     0.67      0.67
# QuadraticDiscriminantAnalysis      0.65               0.65     0.65      0.65
# BernoulliNB                        0.60               0.60     0.60      0.60
# LabelPropagation                   0.58               0.59     0.59      0.57
# LabelSpreading                     0.58               0.59     0.59      0.57
# ExtraTreeClassifier                0.58               0.58     0.58      0.58
# NearestCentroid                    0.57               0.57     0.57      0.56
# GaussianNB                         0.52               0.53     0.53      0.47
# DummyClassifier                    0.48               0.50     0.50      0.31
#
#                                Time Taken
# Model
# LGBMClassifier                       0.50
# RandomForestClassifier               4.06
# XGBClassifier                        1.89
# NuSVC                                3.55
# SVC                                  3.18
# CalibratedClassifierCV               8.57
# ExtraTreesClassifier                 0.96
# LogisticRegression                   0.09
# LinearSVC                            2.08
# RidgeClassifierCV                    0.08
# RidgeClassifier                      0.04
# AdaBoostClassifier                   5.50
# LinearDiscriminantAnalysis           0.14
# BaggingClassifier                    7.30
# DecisionTreeClassifier               1.10
# Perceptron                           0.05
# SGDClassifier                        0.22
# KNeighborsClassifier                 0.08
# PassiveAggressiveClassifier          0.07
# QuadraticDiscriminantAnalysis        0.08
# BernoulliNB                          0.05
# LabelPropagation                     0.41
# LabelSpreading                       0.51
# ExtraTreeClassifier                  0.04
# NearestCentroid                      0.04
# GaussianNB                           0.04
# DummyClassifier                      0.03

# %%
models.to_csv("/mnt/sda1/shivam/Thesis/Grasp Experiment/Data/Results/final/psd-left-vs-right-five.csv")

# %% [markdown]
# ### 2. Hand positions

# %%
X_train, X_eval, y_train, y_eval = train_test_split(eeg_data_five_df.to_numpy(), psd_pos, test_size=0.2, random_state=42)
X_train.shape, X_eval.shape, y_train.shape, y_eval.shape
# Out:
# ((4992, 240), (1248, 240), (4992,), (1248,))

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train, X_eval, y_train, y_eval)
models
# Out:
# 100%|███████████████████████████████████████████| 29/29 [01:09<00:00,  2.41s/it]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.86               0.86    None      0.86
# XGBClassifier                      0.86               0.86    None      0.86
# RandomForestClassifier             0.82               0.82    None      0.82
# ExtraTreesClassifier               0.81               0.81    None      0.81
# BaggingClassifier                  0.77               0.77    None      0.77
# NuSVC                              0.73               0.73    None      0.73
# KNeighborsClassifier               0.68               0.68    None      0.68
# SVC                                0.67               0.67    None      0.67
# DecisionTreeClassifier             0.63               0.63    None      0.63
# AdaBoostClassifier                 0.62               0.62    None      0.62
# CalibratedClassifierCV             0.60               0.60    None      0.60
# LinearSVC                          0.60               0.60    None      0.60
# QuadraticDiscriminantAnalysis      0.60               0.60    None      0.59
# LogisticRegression                 0.59               0.59    None      0.59
# LinearDiscriminantAnalysis         0.58               0.58    None      0.58
# RidgeClassifierCV                  0.58               0.58    None      0.58
# SGDClassifier                      0.58               0.58    None      0.58
# RidgeClassifier                    0.58               0.58    None      0.58
# LabelPropagation                   0.54               0.54    None      0.53
# LabelSpreading                     0.54               0.54    None      0.53
# ExtraTreeClassifier                0.54               0.54    None      0.54
# PassiveAggressiveClassifier        0.54               0.54    None      0.54
# Perceptron                         0.53               0.53    None      0.53
# GaussianNB                         0.43               0.43    None      0.38
# BernoulliNB                        0.40               0.40    None      0.40
# NearestCentroid                    0.39               0.40    None      0.38
# DummyClassifier                    0.33               0.33    None      0.16
#
#                                Time Taken
# Model
# LGBMClassifier                       1.77
# XGBClassifier                        5.05
# RandomForestClassifier               4.55
# ExtraTreesClassifier                 1.02
# BaggingClassifier                    6.96
# NuSVC                                4.84
# KNeighborsClassifier                 0.09
# SVC                                  4.51
# DecisionTreeClassifier               1.19
# AdaBoostClassifier                   5.51
# CalibratedClassifierCV              24.82
# LinearSVC                            7.03
# QuadraticDiscriminantAnalysis        0.09
# LogisticRegression                   0.16
# LinearDiscriminantAnalysis           0.13
# RidgeClassifierCV                    0.08
# SGDClassifier                        0.50
# RidgeClassifier                      0.07
# LabelPropagation                     0.41
# LabelSpreading                       0.52
# ExtraTreeClassifier                  0.04
# PassiveAggressiveClassifier          0.18
# Perceptron                           0.08
# GaussianNB                           0.04
# BernoulliNB                          0.04
# NearestCentroid                      0.04
# DummyClassifier                      0.03

# %%
models.to_csv("/mnt/sda1/shivam/Thesis/Grasp Experiment/Data/Results/final/psd-in-vs-up-vs-down-five.csv")

# %% [markdown]
# ### 3. Open Vs. Close

# %%
X_train, X_eval, y_train, y_eval = train_test_split(eeg_data_all_df.to_numpy(), psd_oc, test_size=0.2, random_state=42)
X_train.shape, X_eval.shape, y_train.shape, y_eval.shape
# Out:
# ((4992, 48), (1248, 48), (4992,), (1248,))

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train, X_eval, y_train, y_eval)
models
# Out:
# 100%|███████████████████████████████████████████| 29/29 [00:18<00:00,  1.58it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.54               0.54     0.54      0.54
# NuSVC                              0.53               0.53     0.53      0.53
# NearestCentroid                    0.53               0.53     0.53      0.52
# XGBClassifier                      0.52               0.52     0.52      0.52
# BaggingClassifier                  0.53               0.52     0.52      0.52
# ExtraTreeClassifier                0.52               0.52     0.52      0.52
# LGBMClassifier                     0.52               0.52     0.52      0.52
# RidgeClassifier                    0.52               0.52     0.52      0.52
# GaussianNB                         0.51               0.52     0.52      0.44
# LogisticRegression                 0.52               0.52     0.52      0.52
# LinearSVC                          0.52               0.52     0.52      0.52
# RidgeClassifierCV                  0.52               0.52     0.52      0.52
# AdaBoostClassifier                 0.52               0.52     0.52      0.52
# LinearDiscriminantAnalysis         0.52               0.52     0.52      0.51
# RandomForestClassifier             0.52               0.52     0.52      0.52
# KNeighborsClassifier               0.51               0.51     0.51      0.51
# SGDClassifier                      0.51               0.51     0.51      0.50
# QuadraticDiscriminantAnalysis      0.50               0.51     0.51      0.44
# SVC                                0.50               0.50     0.50      0.50
# BernoulliNB                        0.50               0.50     0.50      0.50
# LabelPropagation                   0.50               0.50     0.50      0.50
# DummyClassifier                    0.49               0.50     0.50      0.33
# LabelSpreading                     0.50               0.50     0.50      0.50
# DecisionTreeClassifier             0.50               0.50     0.50      0.50
# PassiveAggressiveClassifier        0.50               0.49     0.49      0.48
# CalibratedClassifierCV             0.48               0.49     0.49      0.42
# Perceptron                         0.49               0.49     0.49      0.46
#
#                                Time Taken
# Model
# ExtraTreesClassifier                 0.68
# NuSVC                                4.96
# NearestCentroid                      0.01
# XGBClassifier                        0.62
# BaggingClassifier                    1.71
# ExtraTreeClassifier                  0.02
# LGBMClassifier                       0.18
# RidgeClassifier                      0.02
# GaussianNB                           0.01
# LogisticRegression                   0.05
# LinearSVC                            0.65
# RidgeClassifierCV                    0.02
# AdaBoostClassifier                   1.18
# LinearDiscriminantAnalysis           0.03
# RandomForestClassifier               2.32
# KNeighborsClassifier                 0.05
# SGDClassifier                        0.07
# QuadraticDiscriminantAnalysis        0.02
# SVC                                  1.98
# BernoulliNB                          0.02
# LabelPropagation                     0.40
# DummyClassifier                      0.01
# LabelSpreading                       0.50
# DecisionTreeClassifier               0.29
# PassiveAggressiveClassifier          0.02
# CalibratedClassifierCV               2.52
# Perceptron                           0.02

# %%
models.to_csv("/mnt/sda1/shivam/Thesis/Grasp Experiment/Data/Results/final/psd-open-vs-close-five.csv")
